# %% [markdown]
# # 03 · Visualization
#
# Create clear figures that communicate the main findings.

# %% [markdown]
# ## Project notes
#
# Document decisions, assumptions, and changes as you work.

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

FIGURE_DIR = Path('../figures')
FIGURE_DIR.mkdir(exist_ok=True)

# Example:
# fig, ax = plt.subplots()
# ...
# fig.savefig(FIGURE_DIR / 'main-result.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Next steps
#
# Summarize what should happen next before leaving this notebook.
