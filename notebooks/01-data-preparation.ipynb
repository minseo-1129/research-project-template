# %% [markdown]
# # 01 · Data Preparation
#
# Load, inspect, clean, and document the data used in this project.

# %% [markdown]
# ## Project notes
#
# Document decisions, assumptions, and changes as you work.

# %%
from pathlib import Path
import pandas as pd
import numpy as np

DATA_DIR = Path('../data')

# Example:
# df = pd.read_csv(DATA_DIR / 'example.csv')
# df.head()

# %% [markdown]
# ## Next steps
#
# Summarize what should happen next before leaving this notebook.
