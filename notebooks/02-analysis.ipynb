# %% [markdown]
# # 02 · Statistical Analysis
#
# Run descriptive statistics, models, checks, and sensitivity analyses.

# %% [markdown]
# ## Project notes
#
# Document decisions, assumptions, and changes as you work.

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import statsmodels.api as sm

# Load the analysis-ready dataset and specify models here.

# %% [markdown]
# ## Next steps
#
# Summarize what should happen next before leaving this notebook.
